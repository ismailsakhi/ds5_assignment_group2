# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import statsmodels.api  as sm
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

np.random.seed(2)

x = np.random.uniform(0,10,200)
y = 2 * x ** 2 - 5 * x + 3 + np.random.normal(0,10,200)

#b divide into train and test sets
train_x = x[:80]
train_y = y[:80]

test_x = x[80:]
test_y = y[80:]

inputValuesTrain = {
    'x': x[:80],
    'y': y[:80]
}

data_train = pd.DataFrame(inputValuesTrain)

inputValuesTest = {
    'x': x[80:],
    'y': y[80:]
}

data_test = pd.DataFrame(inputValuesTest)

#c plot the data and determine which relationship exists between the variables and define the regression model
#Plot the dataset
plt.scatter(x,y)
plt.xlabel('x')
plt.ylabel('y')
plt.title('Dataset')
plt.show()

# %%
# From the plot, it appears that there is a quadratic relationship between x and y.
# Therefore, we can define a linear regression model of the form:
# y = β1 x + β0 + ε

# %%
 #d fit the model to the training data

X = sm.add_constant(data_train['x'])
model = sm.OLS(data_train['y'],X)
results = model.fit()

preidicted_train_y = results.predict(X)

print(results.summary())
# y = 14.5261 * x - 30.0576 + ε
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.820
# Method:                 Least Squares   F-statistic:                     361.8
# Date:                Mon, 20 Oct 2025   Prob (F-statistic):           5.00e-31
# Time:                        12:17:22   Log-Likelihood:                -344.71
# No. Observations:                  80   AIC:                             693.4
# Df Residuals:                      78   BIC:                             698.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -30.0576      4.053     -7.416      0.000     -38.127     -21.989
# ...

# %%
#e
